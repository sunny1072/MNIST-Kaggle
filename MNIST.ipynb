# %%
#importing library
import numpy as np
import pandas as pd
import sklearn.preprocessing as pp
from PIL import Image

# %%
df1 = pd.read_csv("C:/Users/sunny/Desktop/ML-NG/kaggle/MNIST/train.csv")
df2 = pd.read_csv("C:/Users/sunny/Desktop/ML-NG/kaggle/MNIST/test.csv")
#df=df.iloc[:28,:]
y_train=df1 ['label']
X_train=df1.drop(['label'], axis=1)
y_train=np.array(y_train)
X_train=np.array(X_train)
X_test=np.array(df2)
X_train = X_train/255
X_test = X_test/255

# %%
#dimension reductionality
from sklearn.decomposition.pca import PCA
import matplotlib.pyplot as plt

#plt.plot(pca.explained_variance_ratio_)
#plt.show()

    
pca = PCA(n_components=75)
pca.fit(X_train)
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)

# %%
def baselinemodel():
    from nltk.tag import sequential
    model =Sequential()
    model.add(Dense(50, input_dim=75, init='normal', activation='sigmoid'))
    model.add(Dense(10, init='normal', activation='sigmoid'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
estimator = KerasClassifier(build_fn=baselinemodel, nb_epoch=200, batch_size=10, verbose=2)
estimator.fit(X_train, y_train)
y_pred=estimator.predict(X_test)
# Out:
# Epoch 1/200
# 13s - loss: 0.6156 - acc: 0.8544
# Epoch 2/200
# 12s - loss: 0.2681 - acc: 0.9222
# Epoch 3/200
# 10s - loss: 0.2281 - acc: 0.9338
# Epoch 4/200
# 13s - loss: 0.2003 - acc: 0.9414
# Epoch 5/200
# 13s - loss: 0.1793 - acc: 0.9485
# Epoch 6/200
# 10s - loss: 0.1622 - acc: 0.9536
# Epoch 7/200
# 11s - loss: 0.1478 - acc: 0.9575
# Epoch 8/200
# 13s - loss: 0.1356 - acc: 0.9610
# Epoch 9/200
# 17s - loss: 0.1250 - acc: 0.9644
# Epoch 10/200
# 18s - loss: 0.1159 - acc: 0.9671
# Epoch 11/200
# 14s - loss: 0.1084 - acc: 0.9689
# Epoch 12/200
# 16s - loss: 0.1012 - acc: 0.9715
# Epoch 13/200
# 20s - loss: 0.0956 - acc: 0.9725
# Epoch 14/200
# 15s - loss: 0.0895 - acc: 0.9750
# Epoch 15/200
# 14s - loss: 0.0849 - acc: 0.9761
# Epoch 16/200
# 13s - loss: 0.0805 - acc: 0.9781
# Epoch 17/200
# 14s - loss: 0.0764 - acc: 0.9788
# Epoch 18/200
# 15s - loss: 0.0731 - acc: 0.9800
# Epoch 19/200
# 16s - loss: 0.0699 - acc: 0.9804
# Epoch 20/200
# 19s - loss: 0.0668 - acc: 0.9812
# ...

# %%
np.savetxt("C:/Users/sunny/Desktop/ML-NG/kaggle/MNIST/result.csv",y_pred, delimiter=",")
